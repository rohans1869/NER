# %% [markdown]
# # NAMED ENTITY RECOGNITION:
#
# 1. The named entities are pre-defined categories chosen according to the use case such as names of people, organizations, places, codes, time notations, monetary values, etc.
#
# 1. NER aims to assign a class to each token (usually a single word) in a sequence. Because of this, NER is also referred to as token classification.

# %%
# !pip install simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.7/250.7 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 78.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 46.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 93.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 106.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 89.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 31.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 88.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
data = pd.read_csv("/content/data2.csv",encoding="latin1" )

# %%
data.head(30)
# Out:
#      Sentence #     Word  POS      Tag
# 0   Sentence: 1    where  NaN      loc
# 1           NaN       is  NaN        O
# 2           NaN    asset  NaN      ast
# 3           NaN    11112  NaN  ast_num
# 4   Sentence: 2    where  NaN      loc
# 5           NaN       is  NaN        O
# 6           NaN    asset  NaN      ast
# 7           NaN    11112  NaN  ast_num
# 8           NaN  located  NaN      loc
# 9   Sentence: 3    where  NaN      loc
# 10          NaN      can  NaN        O
# 11          NaN        I  NaN        O
# 12          NaN     find  NaN        O
# 13          NaN    asset  NaN      ast
# 14          NaN    11112  NaN  ast_num
# 15          NaN      NaN  NaN      NaN
# 16  Sentence: 4    11112  NaN  ast_num
# 17          NaN    asset  NaN      ast
# 18          NaN    where  NaN      loc
# 19          NaN       is  NaN        O
# 20          NaN       it  NaN        O

# %%
data =data.fillna(method ="ffill")

# %%
data.tail(2)
# Out:
#      Sentence # Word  POS Tag
# 19  Sentence: 4   is  NaN   O
# 20  Sentence: 4   it  NaN   O

# %%
data["Sentence #"].nunique(), data["Word"].nunique(), data["Tag"].nunique()
# Out:
# (4, 9, 4)

# %%
data["Tag"].unique()
# Out:
# array(['loc', 'O', 'ast', 'ast_num'], dtype=object)

# %%
data[data["Tag"] == "I-nat"].head(3)
# Out:
# Empty DataFrame
# Columns: [Sentence #, Word, POS, Tag]
# Index: []

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
data["Sentence #"] = LabelEncoder().fit_transform(data["Sentence #"] )

# %%
data.head(5)
# Out:
#    Sentence #   Word  POS      Tag
# 0           0  where  NaN      loc
# 1           0     is  NaN        O
# 2           0  asset  NaN      ast
# 3           0  11112  NaN  ast_num
# 4           1  where  NaN      loc

# %%
data.rename(columns={"Sentence #":"sentence_id","Word":"words","Tag":"labels"}, inplace =True)

# %%
data["labels"] = data["labels"].str.upper()

# %%
X= data[["sentence_id","words"]]
Y =data["labels"]

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size =0.01)

# %%
#building up train data and test data
train_data = pd.DataFrame({"sentence_id":x_train["sentence_id"],"words":x_train["words"],"labels":y_train})
test_data = pd.DataFrame({"sentence_id":x_test["sentence_id"],"words":x_test["words"],"labels":y_test})

# %%
train_data.shape
# Out:
# (20, 3)

# %% [markdown]
# # Model Training

# %%
from simpletransformers.ner import NERModel,NERArgs

# %%
label = data["labels"].unique().tolist()
label
# Out:
# ['LOC', 'O', 'AST', 'AST_NUM']

# %%
args = NERArgs()
args.num_train_epochs = 1
args.learning_rate = 1e-4
args.overwrite_output_dir =True
args.train_batch_size = 32
args.eval_batch_size = 32

# %%
# model = NERModel('bert', 'bert-base-cased',labels=label,args =args)
# model = NERModel('distilbert', 'distilbert-base-multilingual-cased',labels=label,args =args)
model = NERModel('distilbert', 'distilbert-base-uncased',labels=label,args =args)


# distilbert-base-uncased
# Out:
# ...
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForTokenClassification: ['vocab_projector.bias', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForTokenClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# ...

# %%
model.train_model(train_data,eval_data = test_data,acc=accuracy_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/simpletransformers/ner/ner_utils.py:190: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   return [
# ...
# Running Epoch 9 of 10:   0%|          | 0/1 [00:00<?, ?it/s]
# (10, 0.8515945464372635)

# %%
result, model_outputs, preds_list = model.eval_model(test_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/simpletransformers/ner/ner_utils.py:190: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   return [
# ...
# Running Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: LOC seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))

# %%
result
# Out:
# {'eval_loss': 0.853515625, 'precision': 1.0, 'recall': 1.0, 'f1_score': 1.0}

# %%
prediction, model_output = model.predict(["where is asset 00123"])
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prediction
# Out:
# [[{'where': 'LOC'}, {'is': 'O'}, {'asset': 'AST'}, {'00123': 'AST_NUM'}]]

# %%
prediction[0].todict()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-d88b13e86ceb> in <cell line: 1>()
# ----> 1 prediction[0].todict()
#
# AttributeError: 'list' object has no attribute 'todict'

# %% [markdown]
# ###################

# %%
model.model.save_pretrained('model1')
model.tokenizer.save_pretrained('model1')
model.config.save_pretrained('model1/')

# %%
model2 = NERModel('bert','/content/model1', ignore_mismatched_sizes=True)
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at /content/model1 and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([17, 768]) in the checkpoint and torch.Size([9, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([17]) in the checkpoint and torch.Size([9]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
prediction, model_output = model2.predict(["What is the new name of Bangalore"])
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prediction
# Out:
# [[{'What': 'I-LOC'},
#   {'is': 'I-PER'},
#   {'the': 'I-LOC'},
#   {'new': 'I-LOC'},
#   {'name': 'I-LOC'},
#   {'of': 'I-LOC'},
#   {'Bangalore': 'B-PER'}]]

# %%
import pickle

# save the iris classification model as a pickle file
model_pkl_file = "iris_classifier_model.pkl"

with open(model_pkl_file, 'wb') as file:
    pickle.dump(model, file)

# %%
# load model from pickle file
with open("/content/iris_classifier_model.pkl", 'rb') as file:
    model_pkl = pickle.load(file)

# %%
prediction, model_output = model_pkl.predict(["What is the new name of Bangalore"])
prediction
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [[{'What': 'O'},
#   {'is': 'O'},
#   {'the': 'O'},
#   {'new': 'O'},
#   {'name': 'O'},
#   {'of': 'O'},
#   {'Bangalore': 'B-GEO'}]]
